# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Data loading and preprocessing
def load_data(dataset_dir, img_size=(28, 28)):
  rgb_images, binary_images, labels = [], [], []

  # Use relative paths within the function
  data_dir = os.path.join(dataset_dir, 'data')
  binary_dir = os.path.join(dataset_dir, 'data-bin')

  if not os.path.exists(data_dir) or not os.path.exists(binary_dir):
    raise FileNotFoundError(f"Data directories not found in {dataset_dir}")

  for class_idx in range(62):  # 62 classes (0-9, a-z, A-Z)
    rgb_class_dir = os.path.join(data_dir, str(class_idx))
    binary_class_dir = os.path.join(binary_dir, str(class_idx))

    if not os.path.exists(rgb_class_dir) or not os.path.exists(binary_class_dir):
      print(f"Warning: Directory for class {class_idx} not found")
      continue

    for img_file in os.listdir(rgb_class_dir):
      if not img_file.lower().endswith('.png'):
        continue

      # Load RGB and binary images
      rgb_img_path = os.path.join(rgb_class_dir, img_file)
      binary_img_path = os.path.join(binary_class_dir, img_file)

      try:
        rgb_img = Image.open(rgb_img_path).convert('RGB')  # Ensure image is converted to RGB
        binary_img = Image.open(binary_img_path).convert('L')  # Ensure binary image is converted to grayscale
# Convert to float32 for numerical operations
        rgb_img_array = np.array(rgb_img) / 255.0
        binary_img_array = np.array(binary_img) / 255.0      

        rgb_images.append(rgb_img_array)
        binary_images.append(binary_img_array.reshape(*img_size, 1))
        labels.append(class_idx)


      except Exception as e:
        print(f"Error loading image {img_file}: {str(e)}")

  if not rgb_images:
    raise ValueError("No valid images were loaded. Please check the data directories and file permissions.")

  return np.array(rgb_images), np.array(binary_images), np.array(labels)

# %%
# Define the model
def build_ocr_model(input_shape_rgb=(28, 28, 3), input_shape_binary=(28, 28, 1)):
    # RGB input branch
    rgb_input = keras.layers.Input(shape=input_shape_rgb)
    x_rgb = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(rgb_input)
    x_rgb = keras.layers.MaxPooling2D((2, 2))(x_rgb)
    x_rgb = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x_rgb)
    x_rgb = keras.layers.MaxPooling2D((2, 2))(x_rgb)
    x_rgb = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x_rgb)
    x_rgb = keras.layers.MaxPooling2D((2, 2))(x_rgb)
    x_rgb = keras.layers.Flatten()(x_rgb)

    # Binary input branch
    binary_input = keras.layers.Input(shape=input_shape_binary)
    x_binary = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(binary_input)
    x_binary = keras.layers.MaxPooling2D((2, 2))(x_binary)
    x_binary = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x_binary)
    x_binary = keras.layers.MaxPooling2D((2, 2))(x_binary)
    x_binary = keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x_binary)
    x_binary = keras.layers.MaxPooling2D((2, 2))(x_binary)
    x_binary = keras.layers.Flatten()(x_binary)

    # Concatenate both branches
    x = keras.layers.concatenate([x_rgb, x_binary])

    # Fully connected layers
    x = keras.layers.Dense(256, activation='relu')(x)  # Increased units
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.Dense(128, activation='relu')(x)
    x = keras.layers.Dropout(0.5)(x)
    output = keras.layers.Dense(62, activation='softmax')(x)

    model = keras.Model(inputs=[rgb_input, binary_input], outputs=output)
    return model

# %%
def train_ocr_model(dataset_dir):
    # Load and preprocess data
    x_rgb, x_binary, y = load_data(dataset_dir)
    
    # Split data into train and validation sets
    from sklearn.model_selection import train_test_split # type: ignore
    x_rgb_train, x_rgb_val, x_binary_train, x_binary_val, y_train, y_val = train_test_split(
        x_rgb, x_binary, y, test_size=0.2, random_state=42)

    # Convert labels to one-hot encoding
    y_train = keras.utils.to_categorical(y_train, num_classes=62)
    y_val = keras.utils.to_categorical(y_val, num_classes=62)

    # Create and compile the model
    model = build_ocr_model()
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

    # Define callbacks
    early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
    reduce_lr = keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=5)

    # Train the model (adjust epochs and learning rate as needed)
    history = model.fit(
        [x_rgb_train, x_binary_train], y_train,
        validation_data=([x_rgb_val, x_binary_val], y_val),
        epochs=100,  # Adjust based on validation performance
        batch_size=32,
        callbacks=[early_stopping, reduce_lr]
    )
        # Plot training history
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.savefig('ocr_training_history.png')
    plt.close()

    # Evaluate the model
    test_loss, test_accuracy = model.evaluate([x_rgb_val, x_binary_val], y_val)
    print(f"Test accuracy: {test_accuracy:.4f}")

    # Save the model
    model.save('ocr_model.h5')

    print("Training complete. Model saved as 'ocr_model.h5'.")

    return model

# %%
# Run the training
if __name__ == "__main__":
  dataset_dir = r'C:\Users\VIRAT\Projects\OCR\data\dataset-5'

  try:
    trained_model = train_ocr_model(dataset_dir)
    print("OCR model training completed successfully.")

  except Exception as e:
    print(f"An error occurred during training: {str(e)}")
# Out:
# Epoch 1/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.0237 - loss: 4.1440 - val_accuracy: 0.0142 - val_loss: 4.1220 - learning_rate: 0.0010
# Epoch 2/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.0302 - loss: 4.1003 - val_accuracy: 0.0710 - val_loss: 3.9599 - learning_rate: 0.0010
# Epoch 3/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.0725 - loss: 3.8463 - val_accuracy: 0.2469 - val_loss: 3.1574 - learning_rate: 0.0010
# Epoch 4/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.1601 - loss: 3.2847 - val_accuracy: 0.3535 - val_loss: 2.5626 - learning_rate: 0.0010
# Epoch 5/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.2855 - loss: 2.6789 - val_accuracy: 0.4778 - val_loss: 2.1170 - learning_rate: 0.0010
# Epoch 6/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.3270 - loss: 2.3814 - val_accuracy: 0.5222 - val_loss: 1.8326 - learning_rate: 0.0010
# Epoch 7/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.4179 - loss: 2.1236 - val_accuracy: 0.5666 - val_loss: 1.6595 - learning_rate: 0.0010
# Epoch 8/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.4546 - loss: 1.8808 - val_accuracy: 0.5950 - val_loss: 1.4719 - learning_rate: 0.0010
# Epoch 9/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.5037 - loss: 1.7151 - val_accuracy: 0.6359 - val_loss: 1.3406 - learning_rate: 0.0010
# Epoch 10/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.5190 - loss: 1.6063 - val_accuracy: 0.6323 - val_loss: 1.3359 - learning_rate: 0.0010
# Epoch 11/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.5738 - loss: 1.4158 - val_accuracy: 0.6607 - val_loss: 1.2410 - learning_rate: 0.0010
# Epoch 12/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6081 - loss: 1.3012 - val_accuracy: 0.6252 - val_loss: 1.2719 - learning_rate: 0.0010
# Epoch 13/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6093 - loss: 1.2035 - val_accuracy: 0.6767 - val_loss: 1.2027 - learning_rate: 0.0010
# Epoch 14/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.6460 - loss: 1.1131 - val_accuracy: 0.6661 - val_loss: 1.1682 - learning_rate: 0.0010
# Epoch 15/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.6927 - loss: 0.9876 - val_accuracy: 0.6767 - val_loss: 1.1715 - learning_rate: 0.0010
# Epoch 16/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.6940 - loss: 0.9797 - val_accuracy: 0.7069 - val_loss: 1.1107 - learning_rate: 0.0010
# Epoch 17/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.7129 - loss: 0.8650 - val_accuracy: 0.6945 - val_loss: 1.1410 - learning_rate: 0.0010
# Epoch 18/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.7298 - loss: 0.8000 - val_accuracy: 0.6892 - val_loss: 1.0890 - learning_rate: 0.0010
# Epoch 19/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.7265 - loss: 0.8154 - val_accuracy: 0.7123 - val_loss: 1.1199 - learning_rate: 0.0010
# Epoch 20/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.7568 - loss: 0.7634 - val_accuracy: 0.7087 - val_loss: 1.0985 - learning_rate: 0.0010
# Epoch 21/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.7832 - loss: 0.6753 - val_accuracy: 0.7194 - val_loss: 1.0646 - learning_rate: 0.0010
# Epoch 22/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.7771 - loss: 0.7022 - val_accuracy: 0.6945 - val_loss: 1.1142 - learning_rate: 0.0010
# Epoch 23/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.8020 - loss: 0.5897 - val_accuracy: 0.7123 - val_loss: 1.1448 - learning_rate: 0.0010
# Epoch 24/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8151 - loss: 0.5681 - val_accuracy: 0.6963 - val_loss: 1.1346 - learning_rate: 0.0010
# Epoch 25/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8080 - loss: 0.5575 - val_accuracy: 0.7229 - val_loss: 1.1283 - learning_rate: 0.0010
# Epoch 26/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8178 - loss: 0.5342 - val_accuracy: 0.6998 - val_loss: 1.1658 - learning_rate: 0.0010
# Epoch 27/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8338 - loss: 0.4944 - val_accuracy: 0.7123 - val_loss: 1.1387 - learning_rate: 2.0000e-04
# Epoch 28/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8548 - loss: 0.4341 - val_accuracy: 0.7140 - val_loss: 1.1513 - learning_rate: 2.0000e-04
# Epoch 29/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8658 - loss: 0.3933 - val_accuracy: 0.7194 - val_loss: 1.1469 - learning_rate: 2.0000e-04
# Epoch 30/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8722 - loss: 0.3723 - val_accuracy: 0.7158 - val_loss: 1.1888 - learning_rate: 2.0000e-04
# Epoch 31/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.8714 - loss: 0.3719 - val_accuracy: 0.7158 - val_loss: 1.1655 - learning_rate: 2.0000e-04
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6712 - loss: 1.2443
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.7194
# Training complete. Model saved as 'ocr_model.h5'.
# OCR model training completed successfully.

# %%
# Build the model
model = build_ocr_model()

# Display model summary
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 28, 28, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_5       │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 28, 28,    │      1,792 │ input_layer_4[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 28, 28,    │        640 │ input_layer_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_12    │ (None, 14, 14,    │          0 │ conv2d_12[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_15    │ (None, 14, 14,    │          0 │ conv2d_15[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 14, 14,    │     73,856 │ max_pooling2d_12… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 14, 14,    │     73,856 │ max_pooling2d_15… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_13    │ (None, 7, 7, 128) │          0 │ conv2d_13[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (None, 7, 7, 128) │          0 │ conv2d_16[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 7, 7, 256) │    295,168 │ max_pooling2d_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 7, 7, 256) │    295,168 │ max_pooling2d_16… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_14    │ (None, 3, 3, 256) │          0 │ conv2d_14[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_17    │ (None, 3, 3, 256) │          0 │ conv2d_17[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_4 (Flatten) │ (None, 2304)      │          0 │ max_pooling2d_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_5 (Flatten) │ (None, 2304)      │          0 │ max_pooling2d_17… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 4608)      │          0 │ flatten_4[0][0],  │
# │ (Concatenate)       │                   │            │ flatten_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │  1,179,904 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │     32,896 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 128)       │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 62)        │      7,998 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,961,278 (7.48 MB)
#  Trainable params: 1,961,278 (7.48 MB)
#  Non-trainable params: 0 (0.00 B)
