# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Data loading and preprocessing
def load_data(dataset_dir, img_size=(28, 28)):
  rgb_images, binary_images, labels = [], [], []

  # Use relative paths within the function
  data_dir = os.path.join(dataset_dir, 'data')
  binary_dir = os.path.join(dataset_dir, 'data-bin')

  if not os.path.exists(data_dir) or not os.path.exists(binary_dir):
    raise FileNotFoundError(f"Data directories not found in {dataset_dir}")

  for class_idx in range(62):  # 62 classes (0-9, a-z, A-Z)
    rgb_class_dir = os.path.join(data_dir, str(class_idx))
    binary_class_dir = os.path.join(binary_dir, str(class_idx))

    if not os.path.exists(rgb_class_dir) or not os.path.exists(binary_class_dir):
      print(f"Warning: Directory for class {class_idx} not found")
      continue

    for img_file in os.listdir(rgb_class_dir):
      if not img_file.lower().endswith('.png'):
        continue

      # Load RGB and binary images
      rgb_img_path = os.path.join(rgb_class_dir, img_file)
      binary_img_path = os.path.join(binary_class_dir, img_file)

      try:
        rgb_img = Image.open(rgb_img_path).convert('RGB')
        binary_img = Image.open(binary_img_path).convert('L')

        rgb_img_array = np.array(rgb_img) / 255.0
        binary_img_array = np.array(binary_img) / 255.0

        rgb_images.append(rgb_img_array)
        binary_images.append(binary_img_array.reshape(*img_size, 1))
        labels.append(class_idx)

      except Exception as e:
        print(f"Error loading image {img_file}: {str(e)}")

  if not rgb_images:
    raise ValueError("No valid images were loaded. Please check the data directories and file permissions.")

  return np.array(rgb_images), np.array(binary_images), np.array(labels)

# %%
# Define the model
def build_ocr_model(input_shape_rgb=(28, 28, 3), input_shape_binary=(28, 28, 1)):
    # RGB input branch
    rgb_input = keras.layers.Input(shape=input_shape_rgb)
    x_rgb = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(rgb_input)
    x_rgb = keras.layers.MaxPooling2D((2, 2))(x_rgb)
    x_rgb = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x_rgb)
    x_rgb = keras.layers.MaxPooling2D((2, 2))(x_rgb)
    x_rgb = keras.layers.Flatten()(x_rgb)

    # Binary input branch
    binary_input = keras.layers.Input(shape=input_shape_binary)
    x_binary = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(binary_input)
    x_binary = keras.layers.MaxPooling2D((2, 2))(x_binary)
    x_binary = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x_binary)
    x_binary = keras.layers.MaxPooling2D((2, 2))(x_binary)
    x_binary = keras.layers.Flatten()(x_binary)

    # Concatenate both branches
    x = keras.layers.concatenate([x_rgb, x_binary])

    # Fully connected layers
    x = keras.layers.Dense(128, activation='relu')(x)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.Dense(64, activation='relu')(x)
    x = keras.layers.Dropout(0.5)(x)
    output = keras.layers.Dense(62, activation='softmax')(x)

    model = keras.Model(inputs=[rgb_input, binary_input], outputs=output)
    return model

# %%
def train_ocr_model(dataset_dir):
    # Load and preprocess data
    x_rgb, x_binary, y = load_data(dataset_dir)
    
    # Split data into train and validation sets
    from sklearn.model_selection import train_test_split
    x_rgb_train, x_rgb_val, x_binary_train, x_binary_val, y_train, y_val = train_test_split(
        x_rgb, x_binary, y, test_size=0.2, random_state=42)

    # Convert labels to one-hot encoding
    y_train = keras.utils.to_categorical(y_train, num_classes=62)
    y_val = keras.utils.to_categorical(y_val, num_classes=62)

    # Create and compile the model
    model = build_ocr_model()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Define callbacks
    early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
    reduce_lr = keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=5)

    # Train the model
    history = model.fit(
        [x_rgb_train, x_binary_train], y_train,
        validation_data=([x_rgb_val, x_binary_val], y_val),
        epochs=100,  # You can adjust this
        batch_size=32,
        callbacks=[early_stopping, reduce_lr]
    )
        # Plot training history
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.savefig('ocr_training_history.png')
    plt.close()

    # Evaluate the model
    test_loss, test_accuracy = model.evaluate([x_rgb_val, x_binary_val], y_val)
    print(f"Test accuracy: {test_accuracy:.4f}")

    # Save the model
    model.save('ocr_model.h5')

    print("Training complete. Model saved as 'ocr_model.h5'.")

    return model

# %%
# Run the training
if __name__ == "__main__":
    dataset_dir = r'C:\Users\VIRAT\Projects\OCR\data\dataset-5'
    try:
        trained_model = train_ocr_model(dataset_dir)
        print("OCR model training completed successfully.")
    except Exception as e:
        print(f"An error occurred during training: {str(e)}")
# Out:
# Epoch 1/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.0164 - loss: 4.1603 - val_accuracy: 0.0409 - val_loss: 4.1098 - learning_rate: 0.0010
# Epoch 2/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0281 - loss: 4.0912 - val_accuracy: 0.1048 - val_loss: 3.9757 - learning_rate: 0.0010
# Epoch 3/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.0677 - loss: 3.9272 - val_accuracy: 0.1439 - val_loss: 3.6486 - learning_rate: 0.0010
# Epoch 4/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1106 - loss: 3.6333 - val_accuracy: 0.2469 - val_loss: 3.2000 - learning_rate: 0.0010
# Epoch 5/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1599 - loss: 3.3594 - val_accuracy: 0.3073 - val_loss: 2.8556 - learning_rate: 0.0010
# Epoch 6/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1932 - loss: 3.1239 - val_accuracy: 0.3606 - val_loss: 2.6900 - learning_rate: 0.0010
# Epoch 7/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2138 - loss: 2.9742 - val_accuracy: 0.3677 - val_loss: 2.5047 - learning_rate: 0.0010
# Epoch 8/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2164 - loss: 2.8167 - val_accuracy: 0.4281 - val_loss: 2.3778 - learning_rate: 0.0010
# Epoch 9/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2661 - loss: 2.6866 - val_accuracy: 0.4387 - val_loss: 2.2630 - learning_rate: 0.0010
# Epoch 10/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2686 - loss: 2.5936 - val_accuracy: 0.4760 - val_loss: 2.0801 - learning_rate: 0.0010
# Epoch 11/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2976 - loss: 2.5244 - val_accuracy: 0.4813 - val_loss: 2.0202 - learning_rate: 0.0010
# Epoch 12/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3252 - loss: 2.4323 - val_accuracy: 0.5027 - val_loss: 1.9314 - learning_rate: 0.0010
# Epoch 13/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3332 - loss: 2.3081 - val_accuracy: 0.5115 - val_loss: 1.9037 - learning_rate: 0.0010
# Epoch 14/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3265 - loss: 2.3298 - val_accuracy: 0.5293 - val_loss: 1.8287 - learning_rate: 0.0010
# Epoch 15/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3700 - loss: 2.1612 - val_accuracy: 0.5293 - val_loss: 1.8195 - learning_rate: 0.0010
# Epoch 16/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3934 - loss: 2.1151 - val_accuracy: 0.5311 - val_loss: 1.7504 - learning_rate: 0.0010
# Epoch 17/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3922 - loss: 2.0387 - val_accuracy: 0.5400 - val_loss: 1.7262 - learning_rate: 0.0010
# Epoch 18/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3945 - loss: 2.0220 - val_accuracy: 0.5488 - val_loss: 1.6843 - learning_rate: 0.0010
# Epoch 19/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4251 - loss: 1.8473 - val_accuracy: 0.5275 - val_loss: 1.6550 - learning_rate: 0.0010
# Epoch 20/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4366 - loss: 1.8812 - val_accuracy: 0.5560 - val_loss: 1.6078 - learning_rate: 0.0010
# Epoch 21/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4361 - loss: 1.8190 - val_accuracy: 0.5666 - val_loss: 1.5852 - learning_rate: 0.0010
# Epoch 22/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4430 - loss: 1.8115 - val_accuracy: 0.5577 - val_loss: 1.5875 - learning_rate: 0.0010
# Epoch 23/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4621 - loss: 1.7446 - val_accuracy: 0.5648 - val_loss: 1.5903 - learning_rate: 0.0010
# Epoch 24/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4516 - loss: 1.7428 - val_accuracy: 0.5737 - val_loss: 1.5483 - learning_rate: 0.0010
# Epoch 25/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4780 - loss: 1.6667 - val_accuracy: 0.5879 - val_loss: 1.5160 - learning_rate: 0.0010
# Epoch 26/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4841 - loss: 1.6886 - val_accuracy: 0.5808 - val_loss: 1.5422 - learning_rate: 0.0010
# Epoch 27/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4756 - loss: 1.6335 - val_accuracy: 0.5737 - val_loss: 1.5093 - learning_rate: 0.0010
# Epoch 28/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5293 - loss: 1.5277 - val_accuracy: 0.5773 - val_loss: 1.5077 - learning_rate: 0.0010
# Epoch 29/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5131 - loss: 1.5441 - val_accuracy: 0.5861 - val_loss: 1.4889 - learning_rate: 0.0010
# Epoch 30/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4936 - loss: 1.5552 - val_accuracy: 0.5933 - val_loss: 1.4741 - learning_rate: 0.0010
# Epoch 31/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5347 - loss: 1.4997 - val_accuracy: 0.6075 - val_loss: 1.4809 - learning_rate: 0.0010
# Epoch 32/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5520 - loss: 1.4510 - val_accuracy: 0.5950 - val_loss: 1.4852 - learning_rate: 0.0010
# Epoch 33/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5159 - loss: 1.4267 - val_accuracy: 0.5719 - val_loss: 1.4928 - learning_rate: 0.0010
# Epoch 34/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5453 - loss: 1.4141 - val_accuracy: 0.5826 - val_loss: 1.5275 - learning_rate: 0.0010
# Epoch 35/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5460 - loss: 1.3882 - val_accuracy: 0.5808 - val_loss: 1.5016 - learning_rate: 0.0010
# Epoch 36/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5547 - loss: 1.3888 - val_accuracy: 0.5773 - val_loss: 1.4771 - learning_rate: 2.0000e-04
# Epoch 37/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5924 - loss: 1.3019 - val_accuracy: 0.5773 - val_loss: 1.4816 - learning_rate: 2.0000e-04
# Epoch 38/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5853 - loss: 1.3051 - val_accuracy: 0.5879 - val_loss: 1.4587 - learning_rate: 2.0000e-04
# Epoch 39/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5905 - loss: 1.2196 - val_accuracy: 0.6021 - val_loss: 1.4558 - learning_rate: 2.0000e-04
# Epoch 40/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5673 - loss: 1.2979 - val_accuracy: 0.6021 - val_loss: 1.4580 - learning_rate: 2.0000e-04
# Epoch 41/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5788 - loss: 1.3049 - val_accuracy: 0.5950 - val_loss: 1.4666 - learning_rate: 2.0000e-04
# Epoch 42/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5865 - loss: 1.2880 - val_accuracy: 0.5950 - val_loss: 1.4566 - learning_rate: 2.0000e-04
# Epoch 43/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5999 - loss: 1.2180 - val_accuracy: 0.6004 - val_loss: 1.4565 - learning_rate: 2.0000e-04
# Epoch 44/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6013 - loss: 1.2284 - val_accuracy: 0.5950 - val_loss: 1.4581 - learning_rate: 2.0000e-04
# Epoch 45/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5960 - loss: 1.1903 - val_accuracy: 0.5968 - val_loss: 1.4602 - learning_rate: 4.0000e-05
# Epoch 46/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6067 - loss: 1.2187 - val_accuracy: 0.5968 - val_loss: 1.4596 - learning_rate: 4.0000e-05
# Epoch 47/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5906 - loss: 1.1916 - val_accuracy: 0.6021 - val_loss: 1.4619 - learning_rate: 4.0000e-05
# Epoch 48/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6119 - loss: 1.1691 - val_accuracy: 0.5950 - val_loss: 1.4617 - learning_rate: 4.0000e-05
# Epoch 49/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6073 - loss: 1.2177 - val_accuracy: 0.6021 - val_loss: 1.4675 - learning_rate: 4.0000e-05
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5692 - loss: 1.5833
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.6021
# Training complete. Model saved as 'ocr_model.h5'.
# OCR model training completed successfully.
