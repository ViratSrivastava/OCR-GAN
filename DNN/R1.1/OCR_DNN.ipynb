# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Data loading and preprocessing
def load_data(dataset_dir, img_size=(28, 28)):
  rgb_images, binary_images, labels = [], [], []

  # Use relative paths within the function
  data_dir = os.path.join(dataset_dir, 'data')
  binary_dir = os.path.join(dataset_dir, 'data-bin')

  if not os.path.exists(data_dir) or not os.path.exists(binary_dir):
    raise FileNotFoundError(f"Data directories not found in {dataset_dir}")

  for class_idx in range(62):  # 62 classes (0-9, a-z, A-Z)
    rgb_class_dir = os.path.join(data_dir, str(class_idx))
    binary_class_dir = os.path.join(binary_dir, str(class_idx))

    if not os.path.exists(rgb_class_dir) or not os.path.exists(binary_class_dir):
      print(f"Warning: Directory for class {class_idx} not found")
      continue

    for img_file in os.listdir(rgb_class_dir):
      if not img_file.lower().endswith('.png'):
        continue

      # Load RGB and binary images
      rgb_img_path = os.path.join(rgb_class_dir, img_file)
      binary_img_path = os.path.join(binary_class_dir, img_file)

      try:
        rgb_img = Image.open(rgb_img_path).convert('RGB')
        binary_img = Image.open(binary_img_path).convert('L')

        rgb_img_array = np.array(rgb_img) / 255.0
        binary_img_array = np.array(binary_img) / 255.0

        rgb_images.append(rgb_img_array)
        binary_images.append(binary_img_array.reshape(*img_size, 1))
        labels.append(class_idx)

      except Exception as e:
        print(f"Error loading image {img_file}: {str(e)}")

  if not rgb_images:
    raise ValueError("No valid images were loaded. Please check the data directories and file permissions.")

  return np.array(rgb_images), np.array(binary_images), np.array(labels)

# %%
# Define the model
def build_ocr_model(input_shape_rgb=(28, 28, 3), input_shape_binary=(28, 28, 1)):
    # RGB input branch
    rgb_input = keras.layers.Input(shape=input_shape_rgb)
    x_rgb = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(rgb_input)
    x_rgb = keras.layers.MaxPooling2D((2, 2))(x_rgb)
    x_rgb = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x_rgb)
    x_rgb = keras.layers.MaxPooling2D((2, 2))(x_rgb)
    x_rgb = keras.layers.Flatten()(x_rgb)

    # Binary input branch
    binary_input = keras.layers.Input(shape=input_shape_binary)
    x_binary = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(binary_input)
    x_binary = keras.layers.MaxPooling2D((2, 2))(x_binary)
    x_binary = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x_binary)
    x_binary = keras.layers.MaxPooling2D((2, 2))(x_binary)
    x_binary = keras.layers.Flatten()(x_binary)

    # Concatenate both branches
    x = keras.layers.concatenate([x_rgb, x_binary])

    # Fully connected layers
    x = keras.layers.Dense(128, activation='relu')(x)
    x = keras.layers.Dropout(0.5)(x)
    x = keras.layers.Dense(64, activation='relu')(x)
    x = keras.layers.Dropout(0.5)(x)
    output = keras.layers.Dense(62, activation='softmax')(x)

    model = keras.Model(inputs=[rgb_input, binary_input], outputs=output)
    return model

# %%
def train_ocr_model(dataset_dir):
    # Load and preprocess data
    x_rgb, x_binary, y = load_data(dataset_dir)
    
    # Split data into train and validation sets
    from sklearn.model_selection import train_test_split
    x_rgb_train, x_rgb_val, x_binary_train, x_binary_val, y_train, y_val = train_test_split(
        x_rgb, x_binary, y, test_size=0.2, random_state=42)

    # Convert labels to one-hot encoding
    y_train = keras.utils.to_categorical(y_train, num_classes=62)
    y_val = keras.utils.to_categorical(y_val, num_classes=62)

    # Create and compile the model
    model = build_ocr_model()
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Define callbacks
    early_stopping = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
    reduce_lr = keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=5)

    # Train the model
    history = model.fit(
        [x_rgb_train, x_binary_train], y_train,
        validation_data=([x_rgb_val, x_binary_val], y_val),
        epochs=100,  # You can adjust this
        batch_size=32,
        callbacks=[early_stopping, reduce_lr]
    )
        # Plot training history
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.savefig('ocr_training_history.png')
    plt.close()

    # Evaluate the model
    test_loss, test_accuracy = model.evaluate([x_rgb_val, x_binary_val], y_val)
    print(f"Test accuracy: {test_accuracy:.4f}")

    # Save the model
    model.save('ocr_model.h5')

    print("Training complete. Model saved as 'ocr_model.h5'.")

    return model

# %%
# Run the training
if __name__ == "__main__":
    dataset_dir = r'C:\Users\VIRAT\Projects\OCR\data\dataset-5'
    try:
        trained_model = train_ocr_model(dataset_dir)
        print("OCR model training completed successfully.")
    except Exception as e:
        print(f"An error occurred during training: {str(e)}")
# Out:
# Epoch 1/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0187 - loss: 4.1637 - val_accuracy: 0.0568 - val_loss: 4.0989 - learning_rate: 0.0010
# Epoch 2/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0425 - loss: 4.0589 - val_accuracy: 0.0746 - val_loss: 3.9442 - learning_rate: 0.0010
# Epoch 3/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.0687 - loss: 3.9030 - val_accuracy: 0.1741 - val_loss: 3.5483 - learning_rate: 0.0010
# Epoch 4/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1047 - loss: 3.5970 - val_accuracy: 0.2433 - val_loss: 3.1715 - learning_rate: 0.0010
# Epoch 5/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1573 - loss: 3.3724 - val_accuracy: 0.3197 - val_loss: 2.8805 - learning_rate: 0.0010
# Epoch 6/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1858 - loss: 3.1346 - val_accuracy: 0.3677 - val_loss: 2.7251 - learning_rate: 0.0010
# Epoch 7/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2231 - loss: 2.9837 - val_accuracy: 0.3925 - val_loss: 2.4479 - learning_rate: 0.0010
# Epoch 8/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2509 - loss: 2.7585 - val_accuracy: 0.4227 - val_loss: 2.3892 - learning_rate: 0.0010
# Epoch 9/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2703 - loss: 2.7272 - val_accuracy: 0.4476 - val_loss: 2.2170 - learning_rate: 0.0010
# Epoch 10/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2831 - loss: 2.5619 - val_accuracy: 0.4760 - val_loss: 2.1612 - learning_rate: 0.0010
# Epoch 11/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3210 - loss: 2.4286 - val_accuracy: 0.5009 - val_loss: 1.9893 - learning_rate: 0.0010
# Epoch 12/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3206 - loss: 2.4295 - val_accuracy: 0.4867 - val_loss: 1.8961 - learning_rate: 0.0010
# Epoch 13/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3360 - loss: 2.3298 - val_accuracy: 0.4920 - val_loss: 1.8587 - learning_rate: 0.0010
# Epoch 14/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3439 - loss: 2.2379 - val_accuracy: 0.5222 - val_loss: 1.7673 - learning_rate: 0.0010
# Epoch 15/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3781 - loss: 2.1354 - val_accuracy: 0.5560 - val_loss: 1.6702 - learning_rate: 0.0010
# Epoch 16/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3921 - loss: 2.0406 - val_accuracy: 0.5204 - val_loss: 1.6860 - learning_rate: 0.0010
# Epoch 17/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3933 - loss: 2.0236 - val_accuracy: 0.5453 - val_loss: 1.6391 - learning_rate: 0.0010
# Epoch 18/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4257 - loss: 1.9023 - val_accuracy: 0.5577 - val_loss: 1.5749 - learning_rate: 0.0010
# Epoch 19/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4442 - loss: 1.8223 - val_accuracy: 0.5631 - val_loss: 1.5082 - learning_rate: 0.0010
# Epoch 20/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4416 - loss: 1.8991 - val_accuracy: 0.5737 - val_loss: 1.5130 - learning_rate: 0.0010
# Epoch 21/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4615 - loss: 1.7870 - val_accuracy: 0.5844 - val_loss: 1.5006 - learning_rate: 0.0010
# Epoch 22/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4598 - loss: 1.7436 - val_accuracy: 0.5666 - val_loss: 1.4719 - learning_rate: 0.0010
# Epoch 23/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4929 - loss: 1.6348 - val_accuracy: 0.5790 - val_loss: 1.4752 - learning_rate: 0.0010
# Epoch 24/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4755 - loss: 1.6767 - val_accuracy: 0.5702 - val_loss: 1.4468 - learning_rate: 0.0010
# Epoch 25/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4922 - loss: 1.5850 - val_accuracy: 0.5861 - val_loss: 1.4287 - learning_rate: 0.0010
# Epoch 26/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5058 - loss: 1.6066 - val_accuracy: 0.5719 - val_loss: 1.4046 - learning_rate: 0.0010
# Epoch 27/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4991 - loss: 1.5909 - val_accuracy: 0.5844 - val_loss: 1.4376 - learning_rate: 0.0010
# Epoch 28/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5284 - loss: 1.4994 - val_accuracy: 0.5684 - val_loss: 1.4293 - learning_rate: 0.0010
# Epoch 29/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5605 - loss: 1.4041 - val_accuracy: 0.5808 - val_loss: 1.3945 - learning_rate: 0.0010
# Epoch 30/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5333 - loss: 1.4843 - val_accuracy: 0.5755 - val_loss: 1.3849 - learning_rate: 0.0010
# Epoch 31/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5458 - loss: 1.3994 - val_accuracy: 0.5861 - val_loss: 1.3743 - learning_rate: 0.0010
# Epoch 32/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5496 - loss: 1.4094 - val_accuracy: 0.5684 - val_loss: 1.3560 - learning_rate: 0.0010
# Epoch 33/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5413 - loss: 1.4171 - val_accuracy: 0.5844 - val_loss: 1.3705 - learning_rate: 0.0010
# Epoch 34/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5891 - loss: 1.3270 - val_accuracy: 0.5773 - val_loss: 1.3578 - learning_rate: 0.0010
# Epoch 35/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5580 - loss: 1.3592 - val_accuracy: 0.5719 - val_loss: 1.3748 - learning_rate: 0.0010
# Epoch 36/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5447 - loss: 1.3447 - val_accuracy: 0.5666 - val_loss: 1.4435 - learning_rate: 0.0010
# Epoch 37/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5930 - loss: 1.2742 - val_accuracy: 0.5719 - val_loss: 1.3983 - learning_rate: 0.0010
# Epoch 38/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5816 - loss: 1.3024 - val_accuracy: 0.5808 - val_loss: 1.3553 - learning_rate: 2.0000e-04
# Epoch 39/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6139 - loss: 1.1823 - val_accuracy: 0.5755 - val_loss: 1.3607 - learning_rate: 2.0000e-04
# Epoch 40/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6003 - loss: 1.2296 - val_accuracy: 0.5844 - val_loss: 1.3502 - learning_rate: 2.0000e-04
# Epoch 41/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5955 - loss: 1.2058 - val_accuracy: 0.5684 - val_loss: 1.3505 - learning_rate: 2.0000e-04
# Epoch 42/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6030 - loss: 1.2447 - val_accuracy: 0.5826 - val_loss: 1.3499 - learning_rate: 2.0000e-04
# Epoch 43/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6267 - loss: 1.1459 - val_accuracy: 0.5773 - val_loss: 1.3465 - learning_rate: 2.0000e-04
# Epoch 44/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6088 - loss: 1.1419 - val_accuracy: 0.5861 - val_loss: 1.3512 - learning_rate: 2.0000e-04
# Epoch 45/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6016 - loss: 1.2084 - val_accuracy: 0.5861 - val_loss: 1.3447 - learning_rate: 2.0000e-04
# Epoch 46/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6284 - loss: 1.1337 - val_accuracy: 0.5897 - val_loss: 1.3270 - learning_rate: 2.0000e-04
# Epoch 47/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6233 - loss: 1.1150 - val_accuracy: 0.5861 - val_loss: 1.3489 - learning_rate: 2.0000e-04
# Epoch 48/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6060 - loss: 1.1588 - val_accuracy: 0.5879 - val_loss: 1.3395 - learning_rate: 2.0000e-04
# Epoch 49/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6163 - loss: 1.1551 - val_accuracy: 0.5808 - val_loss: 1.3373 - learning_rate: 2.0000e-04
# Epoch 50/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6179 - loss: 1.1299 - val_accuracy: 0.6004 - val_loss: 1.3320 - learning_rate: 2.0000e-04
# Epoch 51/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6272 - loss: 1.1583 - val_accuracy: 0.5897 - val_loss: 1.3434 - learning_rate: 2.0000e-04
# Epoch 52/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6424 - loss: 1.0813 - val_accuracy: 0.5897 - val_loss: 1.3372 - learning_rate: 4.0000e-05
# Epoch 53/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6451 - loss: 1.0729 - val_accuracy: 0.5915 - val_loss: 1.3408 - learning_rate: 4.0000e-05
# Epoch 54/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6424 - loss: 1.0792 - val_accuracy: 0.5897 - val_loss: 1.3380 - learning_rate: 4.0000e-05
# Epoch 55/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6646 - loss: 1.0253 - val_accuracy: 0.5879 - val_loss: 1.3420 - learning_rate: 4.0000e-05
# Epoch 56/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6336 - loss: 1.0739 - val_accuracy: 0.5933 - val_loss: 1.3373 - learning_rate: 4.0000e-05
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5628 - loss: 1.4668
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test accuracy: 0.5897
# Training complete. Model saved as 'ocr_model.h5'.
# OCR model training completed successfully.
